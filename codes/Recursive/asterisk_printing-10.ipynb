# %%
def star(x):
  shp = x//3 # if the function starts by x=27, 'shp' goes to 9
  if (x==3):
    f[1][:3] = ['*',' ','*'] # 3^1  크기의 정사각행렬 중 가운데 행을 정의
    f[0][:3] = ['*']*3 
    f[2][:3] = ['*']*3
    return

  star(shp) # 재귀적 호출 star(27)-> star(9) -> star(3) & if문, for문 (shp = 3, x= 9) ->  if문 & for문 (shp 9, x= 27) 완료

  for i in range(0, x, shp): 
    print(i,'i')
    print('현재 x 값:',x,'현재 shp 값:',shp)
    for j in range(0, x, shp):
      print(j,'j')
      print('현재 x 값:',x,'현재 shp 값:',shp)
      if i != shp or j != shp:
        for k in range(shp):
          print(k,'k')
          f[i+k][j:j+shp] = f[k][:shp]

n = 27 # n = int(input())
f = [[' ' for _ in range(n)] for _ in range(n)]

star(n)

for i in range(n):
  for j in range(n):
    print(f[i][j],end='')
  print()
# Out:
# 0 i
# 현재 x 값: 9 현재 shp 값: 3
# 0 j
# 현재 x 값: 9 현재 shp 값: 3
# 0 k
# 1 k
# 2 k
# 3 j
# 현재 x 값: 9 현재 shp 값: 3
# 0 k
# 1 k
# 2 k
# 6 j
# 현재 x 값: 9 현재 shp 값: 3
# 0 k
# 1 k
# 2 k
# 3 i
# 현재 x 값: 9 현재 shp 값: 3
# 0 j
# 현재 x 값: 9 현재 shp 값: 3
# 0 k
# 1 k
# 2 k
# 3 j
# 현재 x 값: 9 현재 shp 값: 3
# 6 j
# 현재 x 값: 9 현재 shp 값: 3
# 0 k
# 1 k
# 2 k
# 6 i
# 현재 x 값: 9 현재 shp 값: 3
# 0 j
# 현재 x 값: 9 현재 shp 값: 3
# 0 k
# 1 k
# 2 k
# 3 j
# 현재 x 값: 9 현재 shp 값: 3
# 0 k
# 1 k
# 2 k
# 6 j
# 현재 x 값: 9 현재 shp 값: 3
# 0 k
# 1 k
# 2 k
# 0 i
# 현재 x 값: 27 현재 shp 값: 9
# 0 j
# 현재 x 값: 27 현재 shp 값: 9
# 0 k
# 1 k
# 2 k
# 3 k
# 4 k
# 5 k
# 6 k
# 7 k
# 8 k
# 9 j
# 현재 x 값: 27 현재 shp 값: 9
# 0 k
# 1 k
# 2 k
# 3 k
# 4 k
# 5 k
# 6 k
# 7 k
# 8 k
# 18 j
# 현재 x 값: 27 현재 shp 값: 9
# 0 k
# 1 k
# 2 k
# 3 k
# 4 k
# 5 k
# 6 k
# 7 k
# 8 k
# 9 i
# 현재 x 값: 27 현재 shp 값: 9
# 0 j
# 현재 x 값: 27 현재 shp 값: 9
# 0 k
# 1 k
# 2 k
# 3 k
# 4 k
# 5 k
# 6 k
# 7 k
# 8 k
# 9 j
# 현재 x 값: 27 현재 shp 값: 9
# 18 j
# 현재 x 값: 27 현재 shp 값: 9
# 0 k
# 1 k
# 2 k
# 3 k
# 4 k
# ...
